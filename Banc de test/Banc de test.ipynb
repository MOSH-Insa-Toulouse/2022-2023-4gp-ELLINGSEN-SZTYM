# %%
#Courbes de tension et de compression individuelle pour les crayons HB et B

# %%
import matplotlib.pyplot as plt
import numpy as np

# Pour le HB en tension

# Mesure de la résistance et calcul de DeltaR/R en %
R0 = 340.0
R = [340.0, 294.0, 290.0, 286.0, 282.0, 272.0, 268.0, 260.0]
DeltaRdivR = [0, 100 * 46 / R0, 100 * 50 / R0, 100 * 54 / R0, 100 * 58 / R0, 100 * 68 / R0, 100 * 72 / R0, 100 * 80 / R0]

# Calcul de la déformation
# Cercle : De 5 à 2 cm par pas de 0.5 cm
# deformation = e/(2* Rayon_Cercle)
e = 0.3e-3
deformation = [0, e / (2 * 5.0e-2), e / (2 * 4.5e-2), e / (2 * 4.0e-2), e / (2 * 3.5e-2), e / (2 * 3.0e-2), e / (2 * 2.5e-2), e / (2 * 2.0e-2)]

# Force la courbe à passer par 0 et calcule le coefficient de la droite linéaire
DeltaRdivR_zero = np.array(DeltaRdivR) - DeltaRdivR[0]
X = np.array(deformation)
Y = np.array(DeltaRdivR_zero)
m = np.dot(X, Y) / np.dot(X, X)

print(m)

plt.figure(figsize=(10, 10))
plt.xlabel("Deformation")
plt.ylabel("DeltaR/R in %")
plt.title("HB Pencil in tension")
plt.plot(deformation, DeltaRdivR_zero, "x")

plt.plot(X, m * X, "-")

plt.grid()
plt.show()
# Out:
# 3685.7399788331636

# %%
import matplotlib.pyplot as plt
import numpy as np

# Pour le B en tension

# Mesure de la résistance et calcul de DeltaR/R en %
R0 = 690.0
R = [690.0, 680.0, 685.0, 670.0, 650.0, 645.0, 630.0, 610.0]
DeltaRdivR = [0, 100 * 10 / R0, 100 * 15 / R0, 100 * 20 / R0, 100 * 40 / R0, 100 * 45 / R0, 100 * 60 / R0, 100 * 80 / R0]

# Calcul de la déformation
# Cercle : De 5 à 2 cm par pas de 0.5 cm
# deformation = e/(2*Rayon_Cercle)
e = 0.3e-3
deformation = [0, e / (2 * 5.0e-2), e / (2 * 4.5e-2), e / (2 * 4.0e-2), e / (2 * 3.5e-2), e / (2 * 3.0e-2), e / (2 * 2.5e-2), e / (2 * 2.0e-2)]

# Force la courbe à passer par 0 et calcule le coefficient de la droite linéaire
DeltaRdivR_zero = np.array(DeltaRdivR) - DeltaRdivR[0]
X = np.array(deformation)
Y = np.array(DeltaRdivR_zero)
m = np.dot(X, Y) / np.dot(X, X)

print(m)

plt.figure(figsize=(10, 10))
plt.xlabel("Deformation")
plt.ylabel("DeltaR/R in %")
plt.title("B Pencil in tension")
plt.plot(deformation, DeltaRdivR_zero, "x")

plt.plot(X, m * X, "-")

plt.grid()
plt.show()
# Out:
# 1290.101790834234

# %%
import matplotlib.pyplot as plt
import numpy as np

# Pour le B en compression

# Mesure de la résistance et calcul de DeltaR/R en %
R0 = 540.0
R = [540.0, 580.0, 600.0, 620.0, 630.0, 640.0, 655.0, 670.0]
DeltaRdivR = [0, -100 * 40 / R0, -100 * 60 / R0, -100 * 80 / R0, -100 * 90 / R0, -100 * 100 / R0, -100 * 115 / R0, -100 * 130 / R0]

# Calcul de la déformation
# Cercle : De 5 à 2 cm par pas de 0.5 cm
# deformation = e/(2*Rayon_Cercle)
e = 0.3e-3
deformation = [0, e / (2 * 5.0e-2), e / (2 * 4.5e-2), e / (2 * 4.0e-2), e / (2 * 3.5e-2), e / (2 * 3.0e-2), e / (2 * 2.5e-2), e / (2 * 2.0e-2)]

# Force la courbe à passer par 0 et calcule le coefficient de la droite linéaire
DeltaRdivR_zero = np.array(DeltaRdivR) - DeltaRdivR[0]
X = np.array(deformation)
Y = np.array(DeltaRdivR_zero)
m = np.dot(X, Y) / np.dot(X, X)

print(m)

plt.figure(figsize=(10, 10))
plt.xlabel("Deformation")
plt.ylabel("DeltaR/R in %")
plt.title("B Pencil in compression")
plt.plot(deformation, DeltaRdivR_zero, "x")

plt.plot(X, m * X, "-")

plt.grid()
plt.show()
# Out:
# -3458.1895226528777

# %%
import matplotlib.pyplot as plt
import numpy as np

# Pour le HB en compression

# Mesure de la résistance et calcul de DeltaR/R en %
R0 = 500
R = [500, 670.0, 685.0, 695.0, 700.0, 715.0, 730.0, 750.0]
DeltaRdivR = [0, -100 * 170 / R0, -100 * 185 / R0, -100 * 195 / R0, -100 * 200 / R0, -100 * 215 / R0, -100 * 230 / R0, -100 * 250 / R0]

# Calcul de la déformation
# Cercle : De 5 à 2 cm par pas de 0.5 cm
# deformation = e/(2*Rayon_Cercle)
e = 0.3e-3
deformation = [0, e / (2 * 5.0e-2), e / (2 * 4.5e-2), e / (2 * 4.0e-2), e / (2 * 3.5e-2), e / (2 * 3.0e-2), e / (2 * 2.5e-2), e / (2 * 2.0e-2)]

# Force la courbe à passer par 0 et calcule le coefficient de la droite linéaire
DeltaRdivR_zero = np.array(DeltaRdivR) - DeltaRdivR[0]
X = np.array(deformation)
Y = np.array(DeltaRdivR_zero)
m = np.dot(X, Y) / np.dot(X, X)

print(m)

plt.figure(figsize=(10, 10))
plt.xlabel("Deformation")
plt.ylabel("DeltaR/R in %")
plt.title("HB Pencil in compression")
plt.plot(deformation, DeltaRdivR_zero, "x")

plt.plot(X, m * X, "-")

plt.grid()
plt.show()
# Out:
# -8298.50965531345

# %%
#Courbes de tension

# %%
import matplotlib.pyplot as plt
import numpy as np

# Pour le HB en tension
R0 = 340.0
R = [340.0, 294.0, 290.0, 286.0, 282.0, 272.0, 268.0, 260.0]
DeltaRdivR_HBtension = [0, 100 * 46 / R0, 100 * 50 / R0, 100 * 54 / R0, 100 * 58 / R0, 100 * 68 / R0, 100 * 72 / R0, 100 * 80 / R0]
e = 0.3e-3
deformation = [0, e / (2 * 5.0e-2), e / (2 * 4.5e-2), e / (2 * 4.0e-2), e / (2 * 3.5e-2), e / (2 * 3.0e-2), e / (2 * 2.5e-2), e / (2 * 2.0e-2)]

# Force la courbe à passer par 0 et calcule le coefficient de la droite linéaire
DeltaRdivR_HBtension_zero = np.array(DeltaRdivR_HBtension) - DeltaRdivR_HBtension[0]
X = np.array(deformation)
Y = np.array(DeltaRdivR_HBtension_zero)
m_HBtension = np.dot(X, Y) / np.dot(X, X)

print(m_HBtension)

# Pour le B en tension
R0 = 690.0
R = [690.0, 680.0, 685.0, 670.0, 650.0, 645.0, 630.0, 610.0]
DeltaRdivR_Btension = [0, 100 * 10 / R0, 15 * 50 / R0, 20 * 54 / R0, 40 * 58 / R0, 100 * 45 / R0, 100 * 60 / R0, 100 * 80 / R0]

# Force la courbe à passer par 0 et calcule le coefficient de la droite linéaire
DeltaRdivR_Btension_zero = np.array(DeltaRdivR_Btension) - DeltaRdivR_Btension[0]
X = np.array(deformation)
Y = np.array(DeltaRdivR_Btension_zero)
m_Btension = np.dot(X, Y) / np.dot(X, X)

print(m_Btension)

plt.figure(figsize=(10, 10))
plt.xlabel("Deformation")
plt.ylabel("DeltaR/R in %")
plt.title("HB and B pencil in tension")
plt.plot(deformation, DeltaRdivR_HBtension_zero, label="HB pencil", color="r", linestyle="", marker="x")
plt.plot(deformation, DeltaRdivR_Btension_zero, label="B pencil", color="b", linestyle="", marker="x")
plt.legend()

X = np.array(deformation)
plt.plot(X, m_HBtension * X, "r-")
X = np.array(deformation)
plt.plot(X, m_Btension * X, "b-")

plt.grid()
plt.show()
# Out:
# 3685.7399788331636
# 1177.8580575201593

# %%
#Courbes de compression

# %%
import matplotlib.pyplot as plt
import numpy as np

# Pour le HB en compression
R0 = 500
R = [500, 670.0, 685.0, 695.0, 700.0, 715.0, 730.0, 750.0]
DeltaRdivR_HBcompression = [0, -100 * 170 / R0, -100 * 185 / R0, -100 * 195 / R0, -100 * 200 / R0, -100 * 215 / R0, -100 * 230 / R0, -100 * 250 / R0]
e = 0.3e-3
deformation = [0, e / (2 * 5.0e-2), e / (2 * 4.5e-2), e / (2 * 4.0e-2), e / (2 * 3.5e-2), e / (2 * 3.0e-2), e / (2 * 2.5e-2), e / (2 * 2.0e-2)]

# Force la courbe à passer par 0 et calcule le coefficient de la droite linéaire
DeltaRdivR_HBcompression_zero = np.array(DeltaRdivR_HBcompression) - DeltaRdivR_HBcompression[0]
X = np.array(deformation)
Y = np.array(DeltaRdivR_HBcompression_zero)
m_HBcompression = np.dot(X, Y) / np.dot(X, X)

print(m_HBcompression)

# Pour le B en compression
R0 = 540.0
R = [540.0, 580.0, 600.0, 620.0, 630.0, 640.0, 655.0, 670.0]
DeltaRdivR_Bcompression = [0, -100 * 40 / R0, -100 * 60 / R0, -100 * 80 / R0, -100 * 90 / R0, -100 * 100 / R0, -100 * 115 / R0, -100 * 130 / R0]

# Force la courbe à passer par 0 et calcule le coefficient de la droite linéaire
DeltaRdivR_Bcompression_zero = np.array(DeltaRdivR_Bcompression) - DeltaRdivR_Bcompression[0]
X = np.array(deformation)
Y = np.array(DeltaRdivR_Bcompression_zero)
m_Bcompression = np.dot(X, Y) / np.dot(X, X)

print(m_Bcompression)

plt.figure(figsize=(10, 10))
plt.xlabel("Deformation")
plt.ylabel("DeltaR/R in %")
plt.title("HB and B pencil in compression")
plt.plot(deformation, DeltaRdivR_HBcompression_zero, label="HB pencil", color="r", linestyle="", marker="x")
plt.plot(deformation, DeltaRdivR_Bcompression_zero, label="B pencil", color="b", linestyle="", marker="x")
plt.legend()

X = np.array(deformation)
plt.plot(X, m_HBcompression * X, "r-")
X = np.array(deformation)
plt.plot(X, m_Bcompression * X, "b-")

plt.grid()
plt.show()
# Out:
# -8298.50965531345
# -3458.1895226528777

# %%
#Courbe de tension du flexsensor

# %%
import matplotlib.pyplot as plt
import numpy as np

# Pour le Flexsensor en tension
R0 = 33850
R = [33850, 90200, 93400, 105300, 113100, 120500, 130000, 152000]
DeltaRdivR = [0, 100 * 90200 / R0, 100 * 93400 / R0, 100 * 105300 / R0, 100 * 113100 / R0, 100 * 120500 / R0, 100 * 130000 / R0, 100 * 152000 / R0]

# Calcul de la déformation
# Cercle : De 5 à 2 cm par pas de 0.5 cm
# deformation = e / (2 * Rayon_Cercle)
e = 0.3e-3
deformation = [0, e / (2 * 5.0e-2), e / (2 * 4.5e-2), e / (2 * 4.0e-2), e / (2 * 3.5e-2), e / (2 * 3.0e-2), e / (2 * 2.5e-2), e / (2 * 2.0e-2)]

# Force la courbe à passer par 0 et calcule le coefficient de la droite linéaire
DeltaRdivR_zero = np.array(DeltaRdivR) - DeltaRdivR[0]
X = np.array(deformation)
Y = np.array(DeltaRdivR_zero)
m = np.dot(X, Y) / np.dot(X, X)

print(m)

plt.figure(figsize=(10, 10))
plt.xlabel("Deformation")
plt.ylabel("DeltaR/R in %")
plt.title("Flexsensor in tension")
plt.plot(deformation, DeltaRdivR_zero, "x")

X = np.array(deformation)
plt.plot(X, m* X , "-")

plt.grid()
plt.show()
# Out:
# 69318.40538610623
